# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
df= pd.read_csv('/content/drive/MyDrive/PJ/csv/tipos/Guava.csv')
# Out:
# Mounted at /content/drive

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19186 entries, 0 to 19185
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   cliente         19186 non-null  object
#  1   precio_venta    18998 non-null  float64
#  2   peso            19186 non-null  float64
#  3   t_id            19186 non-null  object
#  4   fecha_venta     19120 non-null  object
#  5   hora_venta      19120 non-null  object
#  6   tipo            19186 non-null  object
#  7   fecha_recogida  19186 non-null  object
#  8   hora_recogida   19186 non-null  object
#  9   lote            19186 non-null  object
#  10  marca           19186 non-null  object
#  11  coste_inicial   18650 non-null  float64
#  12  proveedor       19186 non-null  object
# dtypes: float64(3), object(10)
# memory usage: 1.9+ MB

# %%
print(df.describe())
# Out:
#        precio_venta          peso  coste_inicial
# count  18998.000000  19186.000000   18650.000000
# mean       3.500415    300.431953       2.002457
# std        0.701667     99.510346       0.493151
# min        0.368303    -92.837317       0.119227
# 25%        3.030807    233.011657       1.670062
# 50%        3.503037    300.299601       2.000920
# 75%        3.961544    368.118611       2.337458
# max        6.210939    697.067132       3.876357

# %%
print(df.head())
# Out:
#          cliente  precio_venta        peso           t_id fecha_venta  \
# 0  CompraMaestra      1.750873  269.493328  cene00061.png  2022/09/13
# 1  CompraMaestra           NaN  340.204750  cene00631.png  2022/09/22
# 2  CompraMaestra      2.661586  283.861594  cene01561.png  2022/09/24
# 3  CompraMaestra      2.287763  330.722423  cene02371.png  2022/09/08
# 4  CompraMaestra      3.309817   77.509578  cene04441.png  2022/09/10
#
#   hora_venta   tipo fecha_recogida hora_recogida                 lote  \
# 0      05:00  Guava     2022/09/13         05:00  I69T69L48L54M46V78M
# 1      22:00  Guava     2022/09/22         18:00  I69T69L48R51M46V78M
# 2      13:00  Guava     2022/09/24         06:00  I69T69L49Q54M46V78M
# 3      04:00  Guava     2022/09/07         23:00  I69T69L50O55M46V78M
# 4      09:00  Guava     2022/09/10         03:00  I69T69L52P52M46V78M
#
#              marca  coste_inicial                            proveedor
# 0       RicoBosque       0.790900         Mallas AgroProtección García
# 1      JugosoAroma       2.055773             Agrícola Solaris Energía
# 2    EncantoNativo       1.026616         Maquinaria Agrícola Avanzada
# 3     RincónFrutas       1.040863  Herramientas Agroindustriales Gómez
# 4  FantasíaDelicia       2.377540    Reforestación Ecológica VerdeVida

# %%
df['coste_inicial'] = df['coste_inicial'].round(2)
df['peso'] = df['peso'].round(2)
df['precio_venta'] = df['precio_venta'].round(2)

df.head()

# %% [markdown]
# # **PESO**

# %% [markdown]
# Empezamos analizando los PESOS

# %%
peso_minimo = df["peso"].min()
peso_maximo = df["peso"].max()
negativos = df[df["peso"] < 0]
nulos = df[df["peso"].isnull()]

print(f"Peso mínimo: {peso_minimo}")
print(f"Peso máximo: {peso_maximo}")
print(f"Total negativos: {len(negativos)}")
print(f"Total nulos: {len(nulos)}")
# Out:
# Peso mínimo: -92.83731659814202
# Peso máximo: 697.0671319247507
# Total negativos: 30
# Total nulos: 0

# %%
df[df["peso"] < 0]["marca"].value_counts()
# Out:
# marca
# DulceEncanto           3
# AventuraFrutal         3
# BrisaFrutal            3
# ArteFrutal             2
# FantasíaDelicia        2
# RicoBosque             2
# ManjarFruity           1
# FrescuraInigualable    1
# PaladarDorado          1
# GourmetFrutas          1
# DeliciosoEdén          1
# ParaísoFrutal          1
# AromasCelestiales      1
# ExquisitoJardín        1
# TesoroNaturaleza       1
# DulzuraSilvestre       1
# ExóticoManjar          1
# VibranteSabores        1
# TropicalSabor          1
# JugosoAroma            1
# EmbrujoFrutal          1
# Name: count, dtype: int64

# %%
df[df["peso"] < 0]["proveedor"].value_counts()
# Out:
# proveedor
# Fertilizantes Naturales del Valle       4
# Semillero Genético BioCampo             3
# Tractores Eficientes Delgado            2
# Cultivos Hidropónicos Innovagro         2
# Reforestación Ecológica VerdeVida       2
# Agricultura Inteligente TechCultivos    2
# Veterinaria EcoAnimal                   2
# Apícola EcoMiel                         2
# BioCosecha Orgánica                     1
# Avícola San José                        1
# EcoRiego Soluciones                     1
# Ganadería Orgánica TierraFértil         1
# Fitosanitarios BioPro                   1
# Insecticidas Ecológicos Reyes           1
# Semillas Innovadoras S.A.               1
# Agronutrientes del Futuro               1
# Agrícola Solaris Energía                1
# Pecuaria Moderna Alcaraz                1
# Tecnosembradoras del Sur                1
# Name: count, dtype: int64

# %%
df[df["peso"] < 0]["lote"].unique()
# Out:
# array(['M85G86G210I201M51M82K83O90K68J80T71',
#        'M85G86G210I201T48B69C73J69J46V78M',
#        'M85G86G210I201M50L54B69C73J69J46V78M',
#        'M85G86G210I201N51N82K83O90K68B69C73J69J46V78M',
#        'M85G86G48O48P55J80T71', 'M85G86G49O49R46V78M',
#        'M85G86G210I201N51Q55B69C73J69J82K83O90K68J80T71',
#        'M85G86G48O51O50J80T71', 'I69T69L53T56M46V78M',
#        'M85G86G210I201N52N54B69C73J69J46P80M',
#        'M85G86G210I201N52O57B69C73J69J46V78M', 'M85G86G49N56U46V78M',
#        'M85G86G210I201O53N82K83O90K68J80T71', 'C67K78K48O56R49J80T71',
#        'M71E65F65T199K50Q48P82K83O90K68B69C73J69J46V78M',
#        'M85G86G210I201N48Q54B69C73J69J46P80M',
#        'M85G86G210I201M48S57J80T71', 'M85G86G210I201M54U54J80T71',
#        'M85G86G210I201S56U82K83O90K68J80T71',
#        'M85G86G210I201U57S82K83O90K68J74V71',
#        'M85G86G210I201M51U48J80T71',
#        'M85G86G210I201M56R53B69C73J69J46V78M', 'M85G86G48O52Q48J80T71',
#        'M85G86G210I201N50N46V78M', 'M85G86G48N55P51J80T71',
#        'M71E65F65T199K50R51T46V78M', 'M85G86G48M48S55J80T71',
#        'M85G86G48N50L52J80T71', 'M85G86G210I201R48O46V78M',
#        'M85G86G210I201M48M82K83O90K68J74V71'], dtype=object)

# %% [markdown]
# Revisamos si es una marca o proveedor en específico que tiene negativos pero resultan ser los lotes M85G86 y otros no repetitivos.

# %%
print(negativos["peso"])
# Out:
# 735     -79.571417
# 2043    -19.612604
# 4134    -10.306894
# 4271    -13.766870
# 4460     -0.928238
# 4547    -43.554255
# 4848    -14.031104
# 5046     -9.077053
# 5633     -7.069577
# 5954    -17.381527
# 5957    -67.089851
# 6223    -42.178632
# 6548    -37.547210
# 6743    -92.837317
# 6796    -40.329814
# 8099    -38.695552
# 8527    -66.209656
# 8616    -33.449094
# 9911     -8.364154
# 9943    -28.978035
# 10280   -32.024309
# 11558    -7.758434
# 13492    -1.464487
# 13817   -84.043581
# 14525   -63.073584
# 14687    -3.447334
# 15539   -29.810292
# 15581   -26.283259
# 16089    -0.401050
# 17613   -23.350055
# Name: peso, dtype: float64

# %% [markdown]
# Para la poca cantidad que son los eliminamos, no tienen sentido tampoco en positivo.

# %%
filas_peso_negativo = df[df["peso"] < 0]
print(filas_peso_negativo)
# Out:
#                           cliente  precio_venta       peso  \
# 735               La Tienda Justa      3.407284 -79.571417
# 2043              Tienda Familiar      3.639581 -19.612604
# 4134           Mercado del Barrio      3.764968 -10.306894
# 4271           Mercado del Barrio      2.584118 -13.766870
# 4460           Mercado del Barrio      3.734909  -0.928238
# 4547           Alimentación Total      1.418496 -43.554255
# 4848           Alimentación Total      3.151132 -14.031104
# 5046           Alimentación Total      2.960197  -9.077053
# 5633                 CompraRápida      3.582437  -7.069577
# 5954                 CompraRápida      4.140796 -17.381527
# 5957                 CompraRápida      3.905813 -67.089851
# 6223            La Ruta del Sabor      3.325425 -42.178632
# 6548            La Ruta del Sabor      4.327146 -37.547210
# 6743              La Gran Cosecha      2.702481 -92.837317
# 6796              La Gran Cosecha      3.596214 -40.329814
# 8099        EcoMercado Sostenible      3.196648 -38.695552
# 8527                    EcoTienda      3.431732 -66.209656
# 8616                    EcoTienda      4.733413 -33.449094
# 9911           SuperMercado Ideal      4.262998  -8.364154
# 9943           SuperMercado Ideal      4.487169 -28.978035
# 10280            Comercial Fresco      3.929791 -32.024309
# 11558          Mercado Fresco XYZ      3.756204  -7.758434
# 13492       Distribuidora Gourmet      4.118739  -1.464487
# 13817      Distribuidora Nacional      2.384279 -84.043581
# 14525          Delicias del Campo      3.492418 -63.073584
# 14687            La Canasta Feliz      3.894164  -3.447334
# 15539               MaxiAlimentos      3.943833 -29.810292
# 15581               MaxiAlimentos      4.015633 -26.283259
# 16089  Central de Abastos Central      2.900388  -0.401050
# 17613                  MegaAhorro      3.069698 -23.350055
#
#                                     t_id fecha_venta hora_venta   tipo  \
# 735              GuavaÒÇé131 resized.png  2022/09/19      09:00  Guava
# 2043              GuavaÒÇé80 resized.png  2022/09/06      10:00  Guava
# 4134            GuavaÒÇé1206 resized.png  2022/09/24      17:00  Guava
# 4271     GuavaÒÇé232 resized resized.png  2022/09/04      11:00  Guava
# 4460                      Guava03047.png  2022/09/12      15:00  Guava
# 4547                       Guava1316.png  2022/09/03      04:00  Guava
# 4848    GuavaÒÇé2357 resized resized.png  2022/09/28      22:00  Guava
# 5046                      Guava03332.png  2022/09/30      23:00  Guava
# 5633                       cene05881.png  2022/09/02      14:00  Guava
# 5954            GuavaÒÇé2426 resized.jpg  2022/09/13      01:00  Guava
# 5957            GuavaÒÇé2439 resized.png  2022/09/30      08:00  Guava
# 6223                       Guava1289.png  2022/10/01      11:00  Guava
# 6548             GuavaÒÇé352 resized.png  2022/09/27      02:00  Guava
# 6743                      scene03861.png  2022/09/13      12:00  Guava
# 6796   1GuavaÒÇé2504 resized resized.png  2022/09/03      19:00  Guava
# 8099            GuavaÒÇé2056 resized.jpg  2022/09/24      16:00  Guava
# 8527                    GuavaÒÇé1079.png  2022/09/14      02:00  Guava
# 8616                    GuavaÒÇé1696.png  2022/09/14      02:00  Guava
# 9911             GuavaÒÇé789 resized.png  2022/09/05      05:00  Guava
# 9943             GuavaÒÇé997 resized.jpg  2022/09/02      16:00  Guava
# 10280                   GuavaÒÇé1390.png  2022/09/23      14:00  Guava
# 11558           GuavaÒÇé1865 resized.png  2022/09/10      10:00  Guava
# 13492                     Guava03450.png  2022/09/29      13:00  Guava
# 13817                    GuavaÒÇé222.png  2022/09/18      04:00  Guava
# 14525                     Guava02743.png  2022/09/13      14:00  Guava
# 14687                  1GuavaÒÇé2638.png  2022/09/25      16:00  Guava
# 15539                     Guava01077.png  2022/09/03      08:00  Guava
# 15581                     Guava02204.png  2022/09/27      23:00  Guava
# 16089                    GuavaÒÇé603.png  2022/09/12      15:00  Guava
# 17613            GuavaÒÇé101 resized.jpg  2022/09/14      12:00  Guava
#
#       fecha_recogida hora_recogida  \
# 735       2022/09/19         05:00
# 2043      2022/09/06         05:00
# 4134      2022/09/24         11:00
# 4271      2022/09/04         09:00
# 4460      2022/09/12         05:00
# 4547      2022/09/03         03:00
# 4848      2022/09/28         17:00
# 5046      2022/09/30         17:00
# 5633      2022/09/02         12:00
# 5954      2022/09/12         15:00
# 5957      2022/09/30         00:00
# 6223      2022/10/01         05:00
# 6548      2022/09/26         18:00
# 6743      2022/09/13         04:00
# 6796      2022/09/03         09:00
# 8099      2022/09/24         12:00
# 8527      2022/09/13         16:00
# 8616      2022/09/13         17:00
# 9911      2022/09/04         20:00
# 9943      2022/09/02         06:00
# 10280     2022/09/23         05:00
# 11558     2022/09/10         01:00
# 13492     2022/09/29         06:00
# 13817     2022/09/17         23:00
# 14525     2022/09/13         08:00
# 14687     2022/09/25         10:00
# 15539     2022/09/03         08:00
# 15581     2022/09/27         11:00
# 16089     2022/09/12         06:00
# 17613     2022/09/13         23:00
#
#                                                   lote                marca  \
# 735                M85G86G210I201M51M82K83O90K68J80T71      FantasíaDelicia
# 2043                 M85G86G210I201T48B69C73J69J46V78M         ManjarFruity
# 4134              M85G86G210I201M50L54B69C73J69J46V78M           ArteFrutal
# 4271     M85G86G210I201N51N82K83O90K68B69C73J69J46V78M       AventuraFrutal
# 4460                             M85G86G48O48P55J80T71         DulceEncanto
# 4547                               M85G86G49O49R46V78M         DulceEncanto
# 4848   M85G86G210I201N51Q55B69C73J69J82K83O90K68J80T71          BrisaFrutal
# 5046                             M85G86G48O51O50J80T71           RicoBosque
# 5633                               I69T69L53T56M46V78M  FrescuraInigualable
# 5954              M85G86G210I201N52N54B69C73J69J46P80M          BrisaFrutal
# 5957              M85G86G210I201N52O57B69C73J69J46V78M        PaladarDorado
# 6223                               M85G86G49N56U46V78M           ArteFrutal
# 6548               M85G86G210I201O53N82K83O90K68J80T71        GourmetFrutas
# 6743                             C67K78K48O56R49J80T71       AventuraFrutal
# 6796   M71E65F65T199K50Q48P82K83O90K68B69C73J69J46V78M        DeliciosoEdén
# 8099              M85G86G210I201N48Q54B69C73J69J46P80M        ParaísoFrutal
# 8527                        M85G86G210I201M48S57J80T71       AventuraFrutal
# 8616                        M85G86G210I201M54U54J80T71    AromasCelestiales
# 9911               M85G86G210I201S56U82K83O90K68J80T71      ExquisitoJardín
# 9943               M85G86G210I201U57S82K83O90K68J74V71           RicoBosque
# 10280                       M85G86G210I201M51U48J80T71         DulceEncanto
# 11558             M85G86G210I201M56R53B69C73J69J46V78M     TesoroNaturaleza
# 13492                            M85G86G48O52Q48J80T71     DulzuraSilvestre
# 13817                         M85G86G210I201N50N46V78M      FantasíaDelicia
# 14525                            M85G86G48N55P51J80T71          BrisaFrutal
# 14687                       M71E65F65T199K50R51T46V78M        ExóticoManjar
# 15539                            M85G86G48M48S55J80T71      VibranteSabores
# 15581                            M85G86G48N50L52J80T71        TropicalSabor
# 16089                         M85G86G210I201R48O46V78M          JugosoAroma
# 17613              M85G86G210I201M48M82K83O90K68J74V71        EmbrujoFrutal
#
#        coste_inicial                             proveedor
# 735         1.803629          Tractores Eficientes Delgado
# 2043        2.245212                   BioCosecha Orgánica
# 4134        2.085866                      Avícola San José
# 4271        1.003142                   EcoRiego Soluciones
# 4460        1.872256         Insecticidas Ecológicos Reyes
# 4547        1.199841                       Apícola EcoMiel
# 4848        2.041474                 Veterinaria EcoAnimal
# 5046        1.629749  Agricultura Inteligente TechCultivos
# 5633        1.849513                       Apícola EcoMiel
# 5954        2.592325          Tractores Eficientes Delgado
# 5957        1.828100                 Fitosanitarios BioPro
# 6223        2.014182       Ganadería Orgánica TierraFértil
# 6548        2.531045           Semillero Genético BioCampo
# 6743        1.651048     Fertilizantes Naturales del Valle
# 6796        1.432507             Semillas Innovadoras S.A.
# 8099        1.467303     Fertilizantes Naturales del Valle
# 8527        3.005364             Agronutrientes del Futuro
# 8616        2.888545                 Veterinaria EcoAnimal
# 9911        2.306936       Cultivos Hidropónicos Innovagro
# 9943        2.661897           Semillero Genético BioCampo
# 10280       2.376828              Agrícola Solaris Energía
# 11558       2.231737  Agricultura Inteligente TechCultivos
# 13492       1.798480              Pecuaria Moderna Alcaraz
# 13817       1.164413     Reforestación Ecológica VerdeVida
# 14525       1.731374     Fertilizantes Naturales del Valle
# 14687       2.567135     Fertilizantes Naturales del Valle
# 15539       1.994362     Reforestación Ecológica VerdeVida
# 15581       2.364941           Semillero Genético BioCampo
# 16089       1.284179       Cultivos Hidropónicos Innovagro
# 17613       2.122152              Tecnosembradoras del Sur

# %% [markdown]
# Reemplazamos todos los valores negativos por NaN

# %%
df["peso"] = df["peso"].mask(df["peso"] < 0)

# %%
print("Cantidad de pesos mayores de 550 g:", len(df[df['peso'] > 550]))
print("Peso máximo:", df.loc[df['peso'] > 550, 'peso'].max())
# Out:
# Cantidad de pesos mayores de 550 g: 127
# Peso máximo: 697.0671319247507

# %%
import seaborn as sns
import matplotlib.pyplot as plt

costes = df["peso"].dropna()


q1 = costes.quantile(0.25)
q2 = costes.quantile(0.50)
q3 = costes.quantile(0.75)

sns.boxplot(x=costes, orient='h', color='skyblue')

plt.axvline(q1, color='red', linestyle='--', label=f'Q1: {q1:.2f}')
plt.axvline(q2, color='green', linestyle='--', label=f'Mediana: {q2:.2f}')
plt.axvline(q3, color='blue', linestyle='--', label=f'Q3: {q3:.2f}')

plt.title('Diagrama de caja de pesos con cuartiles')
plt.xlabel('Peso (gr.)')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(df["peso"].dropna(), bins=20)
plt.title('Distribución de Pesos')
plt.xlabel('Pesos (g)')
plt.ylabel('Frecuencia')
plt.show()

# %%
Q1_pe = df["peso"].quantile(0.25)
Q3_pe = df["peso"].quantile(0.75)
IQR_pe = Q3_pe - Q1_pe
outliers_pe = df[df["peso"] > Q3_pe + 1.5 * IQR_pe]

print("Total outliers:", outliers_pe["peso"].count())
print(Q1_pe)
print(Q3_pe)
print(IQR_pe)
# Out:
# Total outliers: 61
# 233.31208135489246
# 368.2554749555013
# 134.94339360060886

# %%
print(df[['peso', 't_id']].dropna(subset=['peso']).sort_values(by='peso'))
# Out:
#              peso                             t_id
# 18299    1.149599                 GuavaÒÇé2009.png
# 8071     1.361418                 GuavaÒÇé1869.png
# 14602    1.741622                    cene10591.png
# 2568     2.721312          GuavaÒÇé494 resized.png
# 3280     3.733525                    Guava0321.png
# ...           ...                              ...
# 14794  631.385624         GuavaÒÇé1500 resized.png
# 11025  632.400656  GuavaÒÇé363 resized resized.png
# 7816   679.967487                     ene11731.png
# 7820   685.913161                   scene13921.png
# 12699  697.067132                 GuavaÒÇé1972.png
#
# [19156 rows x 2 columns]

# %% [markdown]
#  El peso medio de una Guava ronda entre los 55 y 165 gramos

# %%
from IPython.display import Image, display

image_path = '/content/drive/MyDrive/PJ/archive/Guava/Guava total/GuavaÒÇé2009.png'

try:
    display(Image(filename=image_path))
except FileNotFoundError:
    print(f"Error: No se encontró el archivo en la ruta {image_path}. Por favor, verifica la ruta de tu imagen.")
except Exception as e:
    print(f"Ocurrió un error al cargar la imagen: {e}")

# %% [markdown]
# En esta imagen vemos el menor peso 1.14gr y podemos observar 6 guavas.

# %%
from IPython.display import Image, display

image_path = '/content/drive/MyDrive/PJ/archive/Guava/guava A/ene11731.png'

try:
    display(Image(filename=image_path))
except FileNotFoundError:
    print(f"Error: No se encontró el archivo en la ruta {image_path}. Por favor, verifica la ruta de tu imagen.")
except Exception as e:
    print(f"Ocurrió un error al cargar la imagen: {e}")

# %% [markdown]
# Aqui en cambio vemos una sola guava y un peso de 679.967487 gr.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# En todas estas imagenes se mustran unicamente una sola guava.
# Mientras que sus pesos son mucho mayores que las siguientes:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Mientras que estas muestran pesos imposibles y todas contienen más de una guava.

# %% [markdown]
# Dejo los pesos aquí y veremos más adelante. Empiezo con coste inicial.

# %% [markdown]
# # **COSTE INICIAL**

# %%
coste_inicial_min = df["coste_inicial"].min()
coste_inicial_max = df["coste_inicial"].max()
negativos_coste = df[df["coste_inicial"] < 0]
nulos_coste = df[df["coste_inicial"].isnull()]

print(f"Coste inicial mínimo: {coste_inicial_min}")
print(f"Coste inicial máximo: {coste_inicial_max}")
print(f"Coste inicial negativos: {len(negativos_coste)}")
print(f"Coste inicial nulos: {len(nulos_coste)}")
# Out:
# Coste inicial mínimo: 0.1192274527951249
# Coste inicial máximo: 3.876357185756469
# Coste inicial negativos: 0
# Coste inicial nulos: 536

# %% [markdown]
# No encontramos negativos y los costes iniciales van desde los 0.11 hasta los 3.87

# %%
import seaborn as sns
import matplotlib.pyplot as plt

costes = df["precio_venta"].dropna()


q1 = costes.quantile(0.25)
q2 = costes.quantile(0.50)
q3 = costes.quantile(0.75)

sns.boxplot(x=costes, orient='h', color='skyblue')

plt.axvline(q1, color='red', linestyle='--', label=f'Q1: {q1:.2f}')
plt.axvline(q2, color='green', linestyle='--', label=f'Mediana: {q2:.2f}')
plt.axvline(q3, color='blue', linestyle='--', label=f'Q3: {q3:.2f}')

plt.title('Diagrama de caja de precio venta con cuartiles')
plt.xlabel('Precio Venta (€)')
plt.legend()

plt.show()

# %% [markdown]
# En el gráfico se ven muchos outliers. Vamos a ver en otro gráfico como visualizamos los datos.

# %%
import matplotlib.pyplot as plt

plt.hist(df["coste_inicial"].dropna(), bins=20)
plt.title('Distribución de Costes Iniciales')
plt.xlabel('Coste Inicial (€)')
plt.ylabel('Frecuencia')
plt.show()

# %%
Q1_ci = df["coste_inicial"].quantile(0.25)
Q3_ci = df["coste_inicial"].quantile(0.75)
IQR_ci = Q3_ci - Q1_ci
outliers_ci = df[df["coste_inicial"] > Q3_ci + 1.5 * IQR_ci]

print("Total outliers:", outliers_ci["coste_inicial"].count())
print(Q1_ci)
print(Q3_ci)
print(IQR_ci)
# Out:
# Total outliers: 64
# 1.670062087557352
# 2.337457623254342
# 0.6673955356969901

# %% [markdown]
# Una vez analizados los costes iniciales y viendo que tenemos 64 outliers y el resto de costes se mueven en la media deben de ser excepciones por algún motivo de calidad, tamaño o imperfecciones de la fruta.
#
# Pasamos a analizar los precios de venta:

# %% [markdown]
# # **PRECIO VENTA**

# %%
peso_minimo_pv = df["precio_venta"].min()
peso_maximo_pv = df["precio_venta"].max()
negativos_pv = df[df["precio_venta"] < 0]
nulos_pv = df[df["precio_venta"].isnull()]

print(f"Precio venta mínimo: {peso_minimo_pv}")
print(f"Precio venta máximo: {peso_maximo_pv}")
print(f"Total negativos: {len(negativos_pv)}")
print(f"Total nulos: {len(nulos_pv)}")
# Out:
# Precio venta mínimo: 0.3683027724713781
# Precio venta máximo: 6.210938601344187
# Total negativos: 0
# Total nulos: 188

# %% [markdown]
# Sabemos que las frutas que no tienen datos de venta es fruta que no ha podido ser vendida porque ha sido dañada durante la distribución. Vamos a comprobar si tienen fecha de venta.

# %%
display(nulos_pv[nulos_pv["fecha_venta"].isnull()])
# Out:
# Empty DataFrame
# Columns: [cliente, precio_venta, peso, t_id, fecha_venta, hora_venta, tipo, fecha_recogida, hora_recogida, lote, marca, coste_inicial, proveedor]
# Index: []

# %% [markdown]
# Ninguno de los 188 nulos es un producto dañado y que no ha sido vendido. Por lo que la empresa ha sufrido una perdida de información o esta información no ha sido registrada correctamente.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

costes = df["precio_venta"].dropna()


q1 = costes.quantile(0.25)
q2 = costes.quantile(0.50)
q3 = costes.quantile(0.75)

sns.boxplot(x=costes, orient='h', color='skyblue')

plt.axvline(q1, color='red', linestyle='--', label=f'Q1: {q1:.2f}')
plt.axvline(q2, color='green', linestyle='--', label=f'Mediana: {q2:.2f}')
plt.axvline(q3, color='blue', linestyle='--', label=f'Q3: {q3:.2f}')

plt.title('Diagrama de caja de precio venta con cuartiles')
plt.xlabel('Precio Venta (€)')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(df["precio_venta"].dropna(), bins=20)
plt.title('Distribución de Precio de Venta')
plt.xlabel('Precio de Venta (€)')
plt.ylabel('')
plt.show()

# %%
Q1_pv = df["precio_venta"].quantile(0.25)
Q3_pv = df["precio_venta"].quantile(0.75)
IQR_pv = Q3_pv - Q1_pv
outliers_pv = df[df["precio_venta"] > Q3_pv + 1.5 * IQR_pv]

print("Total outliers:", outliers_pv["precio_venta"].count())
print(Q1_pv)
print(Q3_pv)
print(IQR_pv)
# Out:
# Total outliers: 77
# 3.030807491945581
# 3.9615441640485574
# 0.9307366721029764

# %%
outliers_pv_ci = pd.merge(outliers_ci, outliers_pv, on='t_id', how='inner')
outliers_pv_ci
# Out:
#                  cliente_x  precio_venta_x      peso_x  \
# 0          La Tienda Justa        6.055768  226.717630
# 1          Tienda Familiar        6.130695  236.425357
# 2           Tienda Selecta        5.510636  407.452601
# 3      SuperAhorro Express        5.549198  263.652977
# 4    EcoMercado Sostenible        5.485459  246.839638
# 5         Comercial Fresco        5.641595  432.358849
# 6       Mercado Fresco XYZ        5.545500  134.171070
# 7        SuperOfertas Plus        5.445869  325.041982
# 8    Distribuidora Gourmet        5.572894  270.784664
# 9   Distribuidora Nacional        6.193196  219.668704
# 10              MegaAhorro        5.708888  215.271221
#
#                                 t_id fecha_venta_x hora_venta_x tipo_x  \
# 0                  1GuavaÒÇé2974.png    2022/09/24        14:00  Guava
# 1             GuavaÒÇé98 resized.jpg    2022/09/15        11:00  Guava
# 2                  1GuavaÒÇé2828.png    2022/09/11        12:00  Guava
# 3           GuavaÒÇé1111 resized.png    2022/09/18        22:00  Guava
# 4   GuavaÒÇé1188 resized resized.png    2022/09/09        05:00  Guava
# 5            GuavaÒÇé941 resized.jpg    2022/09/23        23:00  Guava
# 6   GuavaÒÇé1551 resized resized.png    2022/09/12        00:00  Guava
# 7                      Guava0984.png    2022/09/30        07:00  Guava
# 8           GuavaÒÇé2427 resized.png    2022/09/17        18:00  Guava
# 9                      cene09001.png    2022/09/06        15:00  Guava
# 10                   GuavaÒÇé869.png    2022/09/11        22:00  Guava
#
#    fecha_recogida_x hora_recogida_x  \
# 0        2022/09/24           05:00
# 1        2022/09/15           05:00
# 2        2022/09/11           06:00
# 3        2022/09/18           09:00
# 4        2022/09/09           04:00
# 5        2022/09/23           18:00
# 6        2022/09/11           14:00
# 7        2022/09/29           22:00
# 8        2022/09/17           12:00
# 9        2022/09/06           11:00
# 10       2022/09/11           20:00
#
#                                              lote_x  ...      peso_y  \
# 0                        M71E65F65T199K50U55P46V78M  ...  226.717630
# 1                 M85G86G210I201U56B69C73J69J46P80M  ...  236.425357
# 2                        M71E65F65T199K50T50T46V78M  ...  407.452601
# 3              M85G86G210I201M49M49B69C73J69J46V78M  ...  263.652977
# 4   M85G86G210I201M49T56B69C73J69J82K83O90K68J80T71  ...  246.839638
# 5               M85G86G210I201U52M82K83O90K68J74V71  ...  432.358849
# 6   M85G86G210I201M53Q49B69C73J69J82K83O90K68J80T71  ...  134.171070
# 7                               M85G86G48U56P46V78M  ...  325.041982
# 8              M85G86G210I201N52N55B69C73J69J46V78M  ...  270.784664
# 9                               I69T69L57L48M46V78M  ...  219.668704
# 10                         M85G86G210I201T54U46V78M  ...  215.271221
#
#     fecha_venta_y hora_venta_y tipo_y  fecha_recogida_y  hora_recogida_y  \
# 0      2022/09/24        14:00  Guava        2022/09/24            05:00
# 1      2022/09/15        11:00  Guava        2022/09/15            05:00
# 2      2022/09/11        12:00  Guava        2022/09/11            06:00
# 3      2022/09/18        22:00  Guava        2022/09/18            09:00
# 4      2022/09/09        05:00  Guava        2022/09/09            04:00
# 5      2022/09/23        23:00  Guava        2022/09/23            18:00
# 6      2022/09/12        00:00  Guava        2022/09/11            14:00
# 7      2022/09/30        07:00  Guava        2022/09/29            22:00
# 8      2022/09/17        18:00  Guava        2022/09/17            12:00
# 9      2022/09/06        15:00  Guava        2022/09/06            11:00
# 10     2022/09/11        22:00  Guava        2022/09/11            20:00
#
#                                              lote_y            marca_y  \
# 0                        M71E65F65T199K50U55P46V78M      ParaísoFrutal
# 1                 M85G86G210I201U56B69C73J69J46P80M       ManjarFruity
# 2                        M71E65F65T199K50T50T46V78M        JugosoAroma
# 3              M85G86G210I201M49M49B69C73J69J46V78M         ArteFrutal
# 4   M85G86G210I201M49T56B69C73J69J82K83O90K68J80T71      ExóticoManjar
# 5               M85G86G210I201U52M82K83O90K68J74V71      TropicalSabor
# 6   M85G86G210I201M53Q49B69C73J69J82K83O90K68J80T71      EncantoNativo
# 7                               M85G86G48U56P46V78M  DeliciaNaturaleza
# 8              M85G86G210I201N52N55B69C73J69J46V78M    ExquisitoJardín
# 9                               I69T69L57L48M46V78M      ExóticoManjar
# 10                         M85G86G210I201T54U46V78M      ExóticoManjar
#
#    coste_inicial_y                          proveedor_y
# 0         3.375961          Semillero Genético BioCampo
# 1         3.777639            Agronutrientes del Futuro
# 2         3.605113  Herramientas Agroindustriales Gómez
# 3         3.503643          Cosechadoras Progresivas SA
# 4         3.541231    Fertilizantes Naturales del Valle
# 5         3.876357               Vivero Verde Esperanza
# 6         3.428554      Ganadería Orgánica TierraFértil
# 7         3.400582           Productos Lácteos EcoLeche
# 8         3.604873         Tractores Eficientes Delgado
# 9         3.417019           Productos Lácteos EcoLeche
# 10        3.715903      Cultivos Hidropónicos Innovagro
#
# [11 rows x 25 columns]

# %% [markdown]
# 11 Coinciden.
#
# Vamos a comprobar la norma que tenemos que cumplir que desde día de recogida hasta fecha venta tiene que pasar al menos un día.

# %%
df['fecha_venta'] = pd.to_datetime(df['fecha_venta'], errors='coerce')
df['fecha_recogida'] = pd.to_datetime(df['fecha_recogida'], errors='coerce')

tiempo_diferencia = df['fecha_venta'] - df['fecha_recogida']

al_menos_un_dia = (tiempo_diferencia >= pd.Timedelta(days=1)).all()

print(f"Es verdad que desde fecha_recogida y fecha_venta pasa al menos un día? {al_menos_un_dia}")
# Out:
# Es verdad que desde fecha_recogida y fecha_venta pasa al menos un día? False

# %%
tiempo_diferencia.min()
# Out:
# Timedelta('-30 days +00:00:00')

# %%
tiempo_diferencia.sort_values()
# Out:
# 6739    -30 days
# 12695   -29 days
# 3153    -29 days
# 16674   -29 days
# 18446   -28 days
#           ...
# 16930        NaT
# 17326        NaT
# 18445        NaT
# 18728        NaT
# 18860        NaT
# Length: 19186, dtype: timedelta64[ns]

# %% [markdown]
# Nos encontramos con datos negativos.
# Sabemos que no se pueden realizar reservas antes de la recogida por lo que es un error y la norma no se cumple.
#
# **No en todos los productos pasan 24 horas mínimo desde la recogida hasta la venta.**

# %% [markdown]
# El peso está en gramos. Vamos a comprobar si a cada proveedor no se le venden más de 100Kg de fruta en un solo día.

# %%
venta_dia = df.groupby(['proveedor', 'fecha_venta'])['peso'].sum()

mayor_100kg = (venta_dia > 100000).any()

print(f"¿Algún proveedor recibe más de 100 kg en un solo día? {mayor_100kg}")
# Out:
# ¿Algún proveedor recibe más de 100 kg en un solo día? False

# %% [markdown]
# No se le vende más de 100Kg de guavas a un proveedor en un solo día.
#
# **En el caso de las Guavas esta norma se cumple.**

# %% [markdown]
# Vamos a comprobar que 1 lote solo contiene un tipo de fruta y de una sola marca.

# %%
lote_check = df.groupby('lote').agg({
    'tipo': 'nunique',
    'marca': 'nunique'
}).reset_index()

tipo_check = lote_check[lote_check['tipo'] > 1]
marca_check = lote_check[lote_check['marca'] > 1]

if tipo_check.empty and marca_check.empty:
    print("Cada lote solo contiene un tipo de fruta o una marca.")
else:
    print("Norma incumplida:")
    if not tipo_check.empty:
        print("\nLotes con más de un tipo de fruta:")
        display(tipo_check)
    if not marca_check.empty:
        print("\nLotes con más de una marca:")
        display(marca_check)
# Out:
# Cada lote solo contiene un tipo de fruta o una marca.

# %% [markdown]
# En un solo lote con las Guavas no encontramos más de un tipo de fruta ni más de una marca.
# **Con las Guavas esta norma se cumple.**

# %%
df = df.dropna(subset=['coste_inicial', 'precio_venta'])
df = df[df['coste_inicial'] != 0]
df['rentabilidad'] = ((df['precio_venta'] - df['coste_inicial']) / df['coste_inicial']) * 100

df_lote = df.groupby('lote', as_index=False)[['coste_inicial', 'precio_venta', 'rentabilidad']].mean()

corr = df_lote[['coste_inicial', 'precio_venta', 'rentabilidad']].corr()
display(corr)
# Out:
#                coste_inicial  precio_venta  rentabilidad
# coste_inicial       1.000000      0.696721     -0.583616
# precio_venta        0.696721      1.000000      0.061939
# rentabilidad       -0.583616      0.061939      1.000000

# %%
plt.figure(figsize=(6,5))
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0, fmt=".2f")
plt.title('Correlaciones Económicas por Lote — Guava')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df[['precio_venta', 'coste_inicial', 'peso']].corr()

print(correlation_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Precio Venta, Coste Inicial, and Peso')
plt.show()
# Out:
#                precio_venta  coste_inicial      peso
# precio_venta       1.000000       0.696721  0.009700
# coste_inicial      0.696721       1.000000  0.011645
# peso               0.009700       0.011645  1.000000

# %% [markdown]
# Las correlaciones entre coste inicial y precio venta son de 0.70 mientras que no encontramos correlación entre precio venta y peso ni entre coste inicial y peso. Creemos que esto debería estar totalmente relacionado ya que a mayor peso deberia tener un coste o precio mayor. Esto refuerza la teoria que exponemos de que los pesos no son correctos.

# %% [markdown]
# Aqui dejamos el analisis de las guavas y pasamos a analizar la siguiente fruta.
